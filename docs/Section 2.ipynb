# %%
from preamble import *

# %config InlineBackend.figure_format = 'retina'
# %load_ext lab_black

# %%
# dill.load_session("Geometric_Exponential.pkl")

# %%
import sys

print("ABC version:", abc.__version__)
print("Python version:", sys.version)
print("Numpy version:", np.__version__)
print("PyMC3 version:", pm.__version__)
print("Arviz version:", arviz.__version__)

tic()
# Out:
# ABC version: 0.1.1
# Python version: 3.8.10 (default, May 19 2021, 18:05:58)
# [GCC 7.3.0]
# Numpy version: 1.20.3
# PyMC3 version: 3.11.2
# Arviz version: 0.11.2

# %%
smcArgs = {"numProcs": 40, "verbose": True}

# %%
# Create a pseudorandom number generator
rg = default_rng(1234)

# Parameters of the true model
freq = "geometric"
sev = "exponential"
thetaTrue = (0.8, 5)

# Setting the time horizon
T = 100

# Simulating the claim data
freqs, sevs = abc.simulate_claim_data(rg, T, freq, sev, thetaTrue)

# Simulating the observed data
psi = abc.Psi("sum")
xData = abc.compute_psi(freqs, sevs, psi)

# %%
params = ("p", "δ")
prior = abc.IndependentUniformPrior([(0, 1), (0, 100)], params)
model = abc.Model(freq, sev, psi, prior)

# %%
numIters = 10
popSize = 1000
# %time fit = abc.smc(numIters, popSize, xData, model, **smcArgs)
# Out:
# Starting ABC-SMC with population size of 1000 and sample size of 100 (~> 100) on 40 processes.<p>Finished iteration 0, eps = 22.48, time = 6.0s / 0.1m, ESS = 1000 -> 500, numSims = 1000<p>Finished iteration 1, eps = 10.68, time = 4.0s / 0.1m, ESS = 1326 -> 500, numSims = 2074085<p>Finished iteration 2, eps = 4.49, time = 1.0s / 0.0m, ESS = 1973 -> 500, numSims = 196904<p>Finished iteration 3, eps = 3.22, time = 1.0s / 0.0m, ESS = 1859 -> 500, numSims = 45613<p>Finished iteration 4, eps = 2.58, time = 1.0s / 0.0m, ESS = 1721 -> 500, numSims = 100384<p>Finished iteration 5, eps = 2.22, time = 1.0s / 0.0m, ESS = 1738 -> 500, numSims = 241442<p>Finished iteration 6, eps = 1.96, time = 1.0s / 0.0m, ESS = 1763 -> 500, numSims = 570840<p>Finished iteration 7, eps = 1.80, time = 3.0s / 0.0m, ESS = 1285 -> 500, numSims = 1395215<p>Finished iteration 8, eps = 1.68, time = 6.0s / 0.1m, ESS = 1195 -> 500, numSims = 3532783<p>Finished iteration 9, eps = 1.55, time = 12.0s / 0.2m, ESS = 1576 -> 500, numSims = 7121029<p>Finished iteration 10, eps = 1.55, time = 29.0s / 0.5m, ESS = 1752 -> 864, numSims = 16761704
# Final population dists <= 1.51, ESS = 864
# CPU times: user 12.6 s, sys: 1.61 s, total: 14.2 s
# Wall time: 1min 7s

# %%
fig, axs = plt.subplots(1, len(params), tight_layout=True)

for l, param in enumerate(params):
    pLims = [prior.marginals[l].isf(1), prior.marginals[l].isf(0)]

    abc.weighted_distplot(fit.samples[:, l], fit.weights, ax=axs[l], hist=False)
    axs[l].legend([], frameon=False)
    axs[l].set_title("$" + param + "$")
    axs[l].set_yticks([])
    axs[l].axvline(thetaTrue[l], color="k", linestyle="dashed", alpha=0.8)
sns.despine(left=True)

# %%
# %config InlineBackend.figure_format = 'retina'
# %load_ext nb_black
numItersData = 15

# %% [markdown]
# ## Trying to recover just the claim sizes conditioned on the observed frequency counts

# %%
priorData = abc.IndependentUniformPrior([(0, 100)], ("p", "δ"))
modelData = abc.Model(freqs, sev, psi, priorData)
# %time fitData = abc.smc(numItersData, popSize, xData, modelData, **smcArgs)
# Out:
# Starting ABC-SMC with population size of 1000 and sample size of 100 (~> 100) on 40 processes.<p>Finished iteration 0, eps = 175.24, time = 1.0s / 0.0m, ESS = 1000 -> 500, numSims = 1000<p>Finished iteration 1, eps = 59.30, time = 1.0s / 0.0m, ESS = 1325 -> 500, numSims = 1468<p>Finished iteration 2, eps = 14.68, time = 1.0s / 0.0m, ESS = 1963 -> 500, numSims = 1495<p>Finished iteration 3, eps = 5.16, time = 1.0s / 0.0m, ESS = 1963 -> 500, numSims = 1483<p>Finished iteration 4, eps = 3.09, time = 1.0s / 0.0m, ESS = 1961 -> 500, numSims = 1590<p>Finished iteration 5, eps = 2.48, time = 1.0s / 0.0m, ESS = 1911 -> 500, numSims = 2224<p>Finished iteration 6, eps = 2.13, time = 1.0s / 0.0m, ESS = 1885 -> 500, numSims = 5417<p>Finished iteration 7, eps = 1.89, time = 1.0s / 0.0m, ESS = 1894 -> 500, numSims = 12295<p>Finished iteration 8, eps = 1.71, time = 1.0s / 0.0m, ESS = 1888 -> 500, numSims = 31137<p>Finished iteration 9, eps = 1.57, time = 1.0s / 0.0m, ESS = 1898 -> 500, numSims = 81958<p>Finished iteration 10, eps = 1.47, time = 1.0s / 0.0m, ESS = 1850 -> 500, numSims = 220133<p>Finished iteration 11, eps = 1.38, time = 1.0s / 0.0m, ESS = 1847 -> 500, numSims = 603004<p>Finished iteration 12, eps = 1.30, time = 2.0s / 0.0m, ESS = 1895 -> 500, numSims = 1312868<p>Finished iteration 13, eps = 1.23, time = 6.0s / 0.1m, ESS = 1906 -> 500, numSims = 3361506<p>Finished iteration 14, eps = 1.16, time = 15.0s / 0.2m, ESS = 1910 -> 500, numSims = 9160755<p>Finished iteration 15, eps = 1.16, time = 39.0s / 0.7m, ESS = 1912 -> 956, numSims = 24106421
# Final population dists <= 1.14, ESS = 956
# CPU times: user 16 s, sys: 1.43 s, total: 17.4 s
# Wall time: 1min 13s

# %%
abc.weighted_distplot(fit.samples[:, 1], fit.weights)
abc.weighted_distplot(fitData.samples[:, 0], fitData.weights)
plt.axvline(thetaTrue[1], c="k", ls="--")
plt.yticks([])
sns.despine(left=True)
plt.legend(["Observing sums", "Observing freqs & sums"], frameon=False)

# %% [markdown]
# ## Using summary statistics

# %%
from numba import njit


@njit(nogil=True)
def sumstats(x):
    return np.sum(x)


@njit(nogil=True)
def l1_dist(ssData, ssFake):
    return np.abs(ssData - ssFake)

# %%
# %%time

fitSS = abc.smc(
    numIters,
    popSize,
    xData,
    model,
    sumstats=sumstats,
    distance=l1_dist,
    **smcArgs
)
# Out:
# Starting ABC-SMC with population size of 1000 and sample size of 100 (~> 1) on 40 processes.<p>Finished iteration 0, eps = 2118.65, time = 1.0s / 0.0m, ESS = 1000 -> 500, numSims = 1000<p>Finished iteration 1, eps = 826.78, time = 2.0s / 0.0m, ESS = 1324 -> 500, numSims = 2151146<p>Finished iteration 2, eps = 290.16, time = 1.0s / 0.0m, ESS = 1976 -> 500, numSims = 1101064<p>Finished iteration 3, eps = 118.40, time = 1.0s / 0.0m, ESS = 1851 -> 500, numSims = 53919<p>Finished iteration 4, eps = 45.03, time = 1.0s / 0.0m, ESS = 1696 -> 500, numSims = 112498<p>Finished iteration 5, eps = 18.36, time = 1.0s / 0.0m, ESS = 1695 -> 500, numSims = 250169<p>Finished iteration 6, eps = 7.15, time = 1.0s / 0.0m, ESS = 1772 -> 500, numSims = 666893<p>Finished iteration 7, eps = 2.66, time = 3.0s / 0.0m, ESS = 1767 -> 500, numSims = 1678255<p>Finished iteration 8, eps = 1.15, time = 8.0s / 0.1m, ESS = 1679 -> 500, numSims = 4549798<p>Finished iteration 9, eps = 0.49, time = 16.0s / 0.3m, ESS = 1731 -> 500, numSims = 9863924<p>Finished iteration 10, eps = 0.49, time = 42.0s / 0.7m, ESS = 1783 -> 869, numSims = 24928446
# Final population dists <= 0.33, ESS = 869
# CPU times: user 10.8 s, sys: 736 ms, total: 11.5 s
# Wall time: 1min 17s

# %%
basic_model = pm.Model()

with basic_model:
    # Priors for unknown model parameters
    p = pm.Uniform("p", 0, 1)
    δ = pm.Uniform("δ", 0, 100)

    # Log probability of the compound-sum variable
    def logp(t0, sumData):
        return T * np.log(1 - p) + (T - t0) * np.log(p / δ) - (1 - p) / δ * sumData

    exp_surv = pm.DensityDist(
        "X", logp, observed={"t0": np.sum(xData == 0), "sumData": np.sum(xData)}
    )

    # %time trace = pm.sample(1000, tune=500, chains = 1, random_seed = 1, return_inferencedata=True)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [δ, p]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 00:01<00:00 Sampling chain 0, 0 divergences]
#     </div>
# Sampling 1 chain for 500 tune and 1_000 draw iterations (500 + 1_000 draws total) took 1 seconds.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# CPU times: user 2.08 s, sys: 164 ms, total: 2.25 s
# Wall time: 3.73 s

# %% [markdown]
# ## MLE

# %%
t0 = np.sum(xData == 0)
sumData = np.sum(xData)


def logp(θ):
    p, δ = θ
    return T * np.log(1 - p) + (T - t0) * np.log(p / δ) - (1 - p) / δ * sumData


from scipy.optimize import minimize


def costFn(θ):
    return -logp(θ)


bnds = ((0, 1), (0, None))
x0 = np.array((0.5, 6.0))

minRes = minimize(costFn, x0, bounds=bnds)
print("Optimiser reports a success?", minRes.success)

print(minRes.x, thetaTrue)

pPartialMLE = minRes.x[0]
δPartialMLE = minRes.x[1]
# Out:
# Optimiser reports a success? True
# [0.80999724 5.13679009] (0.8, 5)

# %% [markdown]
# ## MLE using full information

# %%
pMLE = 1 - 1 / (freqs.mean() + 1)
δMLE = sevs.mean()

# %% [markdown]
# ## Plot all together

# %%
fig, axs = plt.subplots(1, len(params), tight_layout=True)
nMCMC = len(trace.posterior["p"][0])

for l, param in enumerate(params):
    pLims = [prior.marginals[l].isf(1), prior.marginals[l].isf(0)]

    abc.weighted_distplot(fit.samples[:, l], fit.weights, ax=axs[l], hist=False)
    abc.weighted_distplot(fitSS.samples[:, l], fitSS.weights, ax=axs[l], hist=False)
    abc.weighted_distplot(
        trace.posterior[param][0], np.ones(nMCMC) / nMCMC, ax=axs[l], hist=False
    )
    axs[l].legend([], frameon=False)
    axs[l].set_title("$" + param + "$")
    axs[l].set_yticks([])
    axs[l].axvline(thetaTrue[l], color="k", linestyle="dashed", alpha=0.8)

sns.despine(left=True)
# save_cropped("../Figures/geometric-exponential-posterior.pdf")

# %%
fig, axs = plt.subplots(1, len(params), tight_layout=True)

for l, param in enumerate(params):
    pLims = [prior.marginals[l].isf(1), prior.marginals[l].isf(0)]

    abc.weighted_distplot(fit.samples[:, l], fit.weights, ax=axs[l], hist=False)
    abc.weighted_distplot(fitSS.samples[:, l], fitSS.weights, ax=axs[l], hist=False)
    abc.weighted_distplot(
        trace.posterior[param][0], np.ones(nMCMC) / nMCMC, ax=axs[l], hist=False
    )
    axs[l].legend([], frameon=False)
    # axs[l].set_title("$" + param + "$")
    axs[l].set_yticks([])
    axs[l].axvline(thetaTrue[l], color="k", linestyle="dashed", alpha=0.8)

draw_prior(prior, axs)
sns.despine(left=True)
save_cropped("../Figures/geometric-exponential-posterior-with-prior.pdf")

# %%
elapsed = toc()
print(f"Notebook time = {elapsed:.0f} secs = {elapsed/60:.2f} mins")
# Out:
# Notebook time = 228 secs = 3.79 mins

# %%
dill.dump_session("Geometric_Exponential.pkl")
